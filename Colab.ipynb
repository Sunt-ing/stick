# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/

# %%
# !git clone https://github.com/Sunt-ing/stick.git
# !ln -s /content/drive/MyDrive/stick /content/stick

# %%
# %cd /content/stick

# %%
# !pip3 install pybind11 numpy typing numdifftools pytest torch

# %%
# !export CXX=/usr/bin/clang++ && make

# %%
# !python3 -m pytest
# you can also run specific test file or test function
# !python3 -m pytest -s -v tests/test_memonger.py
# !python3 -m pytest -k "memonger"
